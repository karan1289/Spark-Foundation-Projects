# %% [markdown]
# # Task 3

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_style('whitegrid')
import warnings
warnings.filterwarnings('ignore')

# %%
data=pd.read_csv('Iris.csv',index_col=0)

# %%
data.head()
# Out:
#     SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# Id
# 1             5.1           3.5            1.4           0.2  Iris-setosa
# 2             4.9           3.0            1.4           0.2  Iris-setosa
# 3             4.7           3.2            1.3           0.2  Iris-setosa
# 4             4.6           3.1            1.5           0.2  Iris-setosa
# 5             5.0           3.6            1.4           0.2  Iris-setosa

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 150 entries, 1 to 150
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   SepalLengthCm  150 non-null    float64
#  1   SepalWidthCm   150 non-null    float64
#  2   PetalLengthCm  150 non-null    float64
#  3   PetalWidthCm   150 non-null    float64
#  4   Species        150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 7.0+ KB

# %%
sns.pairplot(data,hue='Species',diag_kind='kde',height=3)

# %%
x=data.drop('Species',axis=1)
y=data['Species']

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=2)

# %%
from sklearn.tree import DecisionTreeClassifier
classifier=DecisionTreeClassifier()
classifier.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier()

# %%
prediction=classifier.predict(x_test)

# %%
from sklearn.metrics import classification_report
print(classification_report(prediction,y_test))
# Out:
#                  precision    recall  f1-score   support
#
#     Iris-setosa       1.00      1.00      1.00        14
# Iris-versicolor       0.88      0.88      0.88         8
#  Iris-virginica       0.88      0.88      0.88         8
#
#        accuracy                           0.93        30
#       macro avg       0.92      0.92      0.92        30
#    weighted avg       0.93      0.93      0.93        30

# %% [raw]
# We have accuracy of 93% with precision 100% and recall 100%.

# %%
classifier.predict([[5.0,5.0,2.5,1.3]])
# Out:
# array(['Iris-versicolor'], dtype=object)

# %%
from sklearn import tree
plt.figure(figsize=(15,10))
tree.plot_tree(classifier,filled=True)
# Out:
# [Text(334.8, 489.24, 'X[2] <= 2.35\ngini = 0.665\nsamples = 120\nvalue = [36, 42, 42]'),
#  Text(251.10000000000002, 380.52000000000004, 'gini = 0.0\nsamples = 36\nvalue = [36, 0, 0]'),
#  Text(418.5, 380.52000000000004, 'X[3] <= 1.65\ngini = 0.5\nsamples = 84\nvalue = [0, 42, 42]'),
#  Text(167.4, 271.8, 'X[2] <= 4.95\ngini = 0.127\nsamples = 44\nvalue = [0, 41, 3]'),
#  Text(83.7, 163.08000000000004, 'gini = 0.0\nsamples = 40\nvalue = [0, 40, 0]'),
#  Text(251.10000000000002, 163.08000000000004, 'X[3] <= 1.55\ngini = 0.375\nsamples = 4\nvalue = [0, 1, 3]'),
#  Text(167.4, 54.360000000000014, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 3]'),
#  Text(334.8, 54.360000000000014, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0]'),
#  Text(669.6, 271.8, 'X[2] <= 4.85\ngini = 0.049\nsamples = 40\nvalue = [0, 1, 39]'),
#  Text(585.9, 163.08000000000004, 'X[1] <= 3.1\ngini = 0.375\nsamples = 4\nvalue = [0, 1, 3]'),
#  Text(502.20000000000005, 54.360000000000014, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 3]'),
#  Text(669.6, 54.360000000000014, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0]'),
#  Text(753.3000000000001, 163.08000000000004, 'gini = 0.0\nsamples = 36\nvalue = [0, 0, 36]')]
